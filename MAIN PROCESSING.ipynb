# %% [markdown]
# # WDA -> Floop Script
#
#
# ## The three files in play here
#
#
# WDAfloopscrape.json - the main json data scrape.
#
# labels.json - the labels for the scrape. there's some duplication sorted out below.
#
# data.json - the data behind the floop graphic. we're trying to ammend the this json with info taken off WDA.

# %%
import json

# for now we'll ammend to the best choice where there are duplicate labels for a classification
# the ones shown below are the only duplicate labels for classifications in the scrape.
with open("labels.json", "r") as labels_file:   
    labels = json.load(labels_file)

    for key in labels.keys():    
        if labels[key] == ['Type', 'Geography', 'Area']: labels[key] = 'Area'
        if labels[key] == ['Year', 'Time', 'Month']: labels[key] = 'Time'
        if labels[key] == ['Household characteristics', 'Household Characteristics']: labels[key] = 'Household Characteristics'
        if labels[key] == ['Flow of Travel', 'Type']: labels[key] = 'Flow of Travel'
        if labels[key] == ['Seasonal Adjustment', 'SA / NSA']: labels[key] = 'Seasonal Adjustment'
        if labels[key] == ['Component', 'Standard Industrial Trade Classification (SITC)']: labels[key] = 'Standard Industrial Trade Classification (SITC)'

# %% [markdown]
# ## What the scrape looks like, just one sample (the ASHE07E dataset)

# %%
# import json
from pprint import pprint

with open("WDAfloopscrape.json", "r") as main_file:   
    scrape = json.load(main_file)
    
    pprint({'ASHE07E':scrape['ASHE07E']})
# Out:
# {'ASHE07E': {'context': 'Economic',
#              'name': 'Earnings by place of work',
#              'topics': ['CL_0000695',
#                         'CL_0000700',
#                         'CL_0000699',
#                         'CL_0000693',
#                         'CL_0000712',
#                         'CL_0000696',
#                         'CL_0000635',
#                         '2013WARDH'],
#              'url': '<p>Not implemented yet</p>'}}

# %% [markdown]
# ## Make a Dict of resources already defined

# %%
with open("data.json", "r") as labels_file:
    
    floopdata = json.load(labels_file)
    
    resources = [x for x in floopdata['data'] if '/topic/' in x]
    
    existingResources = {}
    for r in resources:
        if floopdata['data'][r]['type'] == 'topic':
            existingResources.update({floopdata['data'][r]['name']:floopdata['data'][r]['id']})
            
    # so thisis whats already defined put in a dict
    pprint (existingResources)
# Out:
# {'acorn': 'http://ons.floop.org.uk/resource/topic/51',
#  'age': 'http://ons.floop.org.uk/resource/topic/32',
#  'age band': 'http://ons.floop.org.uk/resource/topic/3',
#  'age group': 'http://ons.floop.org.uk/resource/topic/28',
#  'broad industry sector': 'http://ons.floop.org.uk/resource/topic/26',
#  'continent': 'http://ons.floop.org.uk/resource/topic/58',
#  'country': 'http://ons.floop.org.uk/resource/topic/59',
#  'country of birth': 'http://ons.floop.org.uk/resource/topic/11',
#  'department': 'http://ons.floop.org.uk/resource/topic/57',
#  'dependent children': 'http://ons.floop.org.uk/resource/topic/14',
#  'disability': 'http://ons.floop.org.uk/resource/topic/12',
#  'do conditions cause difficulty': 'http://ons.floop.org.uk/resource/topic/30',
#  'employed/self-employed': 'http://ons.floop.org.uk/resource/topic/48',
#  'employment size band': 'http://ons.floop.org.uk/resource/topic/46',
#  'ethnicity': 'http://ons.floop.org.uk/resource/topic/9',
#  'eu/non-eu': 'http://ons.floop.org.uk/resource/topic/47',
#  'flexible working hours': 'http://ons.floop.org.uk/resource/topic/17',
#  'full/part time': 'http://ons.floop.org.uk/resource/topic/4',
#  'full/part-time': 'http://ons.floop.org.uk/resource/topic/49',
#  'gender': 'http://ons.floop.org.uk/resource/topic/2',
#  'gender. age': 'http://ons.floop.org.uk/resource/topic/60',
#  'high/low technology industries': 'http://ons.floop.org.uk/resource/topic/25',
#  'houshold composition': 'http://ons.floop.org.uk/resource/topic/42',
#  'imd 2010 decile': 'http://ons.floop.org.uk/resource/topic/43',
#  'includes ytd figures': 'http://ons.floop.org.uk/resource/topic/39',
#  'income band': 'http://ons.floop.org.uk/resource/topic/44',
#  'income group': 'http://ons.floop.org.uk/resource/topic/54',
#  'income quintile': 'http://ons.floop.org.uk/resource/topic/40',
#  'index of deprivation': 'http://ons.floop.org.uk/resource/topic/53',
#  'learning disability': 'http://ons.floop.org.uk/resource/topic/36',
#  'length of service': 'http://ons.floop.org.uk/resource/topic/18',
#  'long-standing conditions': 'http://ons.floop.org.uk/resource/topic/29',
#  'managerial status': 'http://ons.floop.org.uk/resource/topic/16',
#  'marital status': 'http://ons.floop.org.uk/resource/topic/55',
#  'mental health condition': 'http://ons.floop.org.uk/resource/topic/35',
#  'nationality': 'http://ons.floop.org.uk/resource/topic/10',
#  'ns-sec': 'http://ons.floop.org.uk/resource/topic/52',
#  'penalty band': 'http://ons.floop.org.uk/resource/topic/38',
#  'permanent/temporary': 'http://ons.floop.org.uk/resource/topic/5',
#  'previous pregnancies': 'http://ons.floop.org.uk/resource/topic/37',
#  'qualification level': 'http://ons.floop.org.uk/resource/topic/13',
#  'quintile': 'http://ons.floop.org.uk/resource/topic/45',
#  'religion': 'http://ons.floop.org.uk/resource/topic/33',
#  'respondent': 'http://ons.floop.org.uk/resource/topic/31',
#  'sampling sector': 'http://ons.floop.org.uk/resource/topic/27',
#  'sector': 'http://ons.floop.org.uk/resource/topic/6',
#  'sexuality': 'http://ons.floop.org.uk/resource/topic/34',
#  'sic': 'http://ons.floop.org.uk/resource/topic/23',
#  'sic 2007': 'http://ons.floop.org.uk/resource/topic/8',
#  'size of enterprise': 'http://ons.floop.org.uk/resource/topic/24',
#  'soc': 'http://ons.floop.org.uk/resource/topic/50',
#  'soc 2000': 'http://ons.floop.org.uk/resource/topic/20',
#  'soc 2010': 'http://ons.floop.org.uk/resource/topic/7',
#  'sport': 'http://ons.floop.org.uk/resource/topic/56',
#  'tenure': 'http://ons.floop.org.uk/resource/topic/41',
#  'trade union wage premium': 'http://ons.floop.org.uk/resource/topic/22',
#  'union membership': 'http://ons.floop.org.uk/resource/topic/21',
#  'weekly earnings in main job': 'http://ons.floop.org.uk/resource/topic/19',
#  'workplace size': 'http://ons.floop.org.uk/resource/topic/15'}

# %% [markdown]
# ## A dataset as represented in the data.json file on floop

# %% [raw]
# http://ons.floop.org.uk/resource/dataset/153: {
#     type: "http://ons.floop.org.uk/resource/organisation/18",
#     name: "Statistics on International Development 2015",
#     id: "http://ons.floop.org.uk/resource/dataset/153",
#     docsLink: "dataset?name=Statistics%20on%20International%20Development%202015",
#     depends: [
#         "http://ons.floop.org.uk/resource/topic/57",
#         "http://ons.floop.org.uk/resource/topic/58",
#         "http://ons.floop.org.uk/resource/topic/59"
#             ],
#     dependedOnBy: [ ]
#     },

# %% [markdown]
# ## Modding the data.json from floop
#
# assumptions:
# we'll start the new datasets at 155, that seems to be the next unused number
#
# we'll start topics at 61 for the same reason
#
# we'll use 24 to represent ONS for the same reason.
#
# TODO - have to define org 24 as ONS somehow. also need to calculate the numbers so this whole thing becomes repeatable.

# %% [markdown]
# we need to define the datasets one at a time, only adding a new resource if we cant match the ONS topic to a pre-existing resource.

# %%
# TODO - should be calculated not stated
datasetCount = 155
topicsCount = 61
orgCount = 24


# we'll build the ammendments as a whole seperate dict then append to data.json later
with open("WDAfloopscrape.json", "r") as scrape_file:   
    scrape = json.load(scrape_file)
    
    
    """
    Clean out the horrid topic (txxxx) thing in our labels dict
    """
    for key in scrape:
        for t in scrape[key]['topics']:
            if '(T' in labels[t]:
                labels[t] = labels[t].split('(T')[0].strip()
    
    """
    Build a bigger data.json
    """
    ammendments = {}
    for key in scrape:
        
        # list of all resources we'll need to define for this dataset, and another of already defined ones we just need to list
        undefined = []
        defined = []
        
        #pprint (labels)
        
        for topic in scrape[key]['topics']:
            
            # is this topic already defined?
            if labels[topic].lower() in existingResources.keys():
                defined.append(existingResources[labels[topic].lower()])
                
            else:
                undefined.append(labels[topic].lower())
                
        
        # build a dict of undefined topics as name:uri
        definitionsToDo = {}
        for u in undefined:
            definitionsToDo.update({u:'http://ons.floop.org.uk/resource/topic/' + str(topicsCount)})
            topicsCount += 1
        
        # use the lit of already defined topics/resources and definitionsToDo to build the 'depends' list for dataset 
        depends = []
        for d in defined:
            depends.append(d)
        for defo in definitionsToDo:
            depends.append(definitionsToDo[defo])
        
        # build the dataset dict
        dset = 'http://ons.floop.org.uk/resource/dataset/' + str(datasetCount)
        _type = 'http://ons.floop.org.uk/resource/organisation/' + str(orgCount)
        name = scrape[key]['name']
        _id = key
        docsLink = "https://www.ons.gov.uk/"
        
        ammendments.update({dset:{'type':_type, 'name':name, 'id':_id, 'docslink':docsLink, 'depends':depends, 'dependedOnBy':[]}})
        
        # add dataset counter
        datasetCount +=1 
        
        
        # build the dicts for out newly minted resources
        # this is what we built the definitionsToDo dict for 
        """
        http://ons.floop.org.uk/resource/topic/2: {
            type: "topic",
            name: "gender",
            id: "http://ons.floop.org.uk/resource/topic/2",
            depends: [ ],
            dependedOnBy: [ ]
            }
        """
        for reslabel in definitionsToDo.keys():
            uri = definitionsToDo[reslabel]
            ammendments.update({uri:{'type':'topic', 'name':reslabel, 'id':uri, 'depends':[], 'dependedOnBy':[]}})
        
        
        # Add out newly defined recources to existingResources ready for next entry
        for key in definitionsToDo:
            existingResources.update({key:definitionsToDo[key]})

# Export to json file
with open("justTheAmmendments.json", "w") as outfile:
    json.dump(ammendments, outfile)

# %% [markdown]
# ## Preview The Json we're going to append onto data.json

# %%
# Preview the ammendments
pprint(ammendments)
# Out:
# {'http://ons.floop.org.uk/resource/dataset/1000': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/70',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC6118EW 2',
#                                                    'name': 'Industry by sex',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1001': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/98',
#                                                                'http://ons.floop.org.uk/resource/topic/124',
#                                                                'http://ons.floop.org.uk/resource/topic/63',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC4406EW',
#                                                    'name': 'Tenure by number '
#                                                            'of persons per '
#                                                            'room in household '
#                                                            'by accommodation '
#                                                            'type',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1002': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/61',
#                                                                'http://ons.floop.org.uk/resource/topic/65',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC3407EW',
#                                                    'name': 'Long-term health '
#                                                            'problem or '
#                                                            'disability by car '
#                                                            'or van '
#                                                            'availability by '
#                                                            'age',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1003': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/82',
#                                                                'http://ons.floop.org.uk/resource/topic/63',
#                                                                'http://ons.floop.org.uk/resource/topic/101'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC4601EW',
#                                                    'name': 'Tenure by economic '
#                                                            'activity by age - '
#                                                            'Household '
#                                                            'Reference Persons',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1004': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/11',
#                                                                'http://ons.floop.org.uk/resource/topic/69',
#                                                                'http://ons.floop.org.uk/resource/topic/127',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'CT0071',
#                                                    'name': 'Highest level of '
#                                                            'qualification by '
#                                                            'year of arrival in '
#                                                            'the UK by country '
#                                                            'of birth by age '
#                                                            '(national)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1005': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/293',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'CPI15',
#                                                    'name': 'Consumer Prices '
#                                                            'Index (COICOP)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1006': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/233',
#                                                                'http://ons.floop.org.uk/resource/topic/68',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC1118EW',
#                                                    'name': 'Age of youngest '
#                                                            'dependent child by '
#                                                            'family type',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1007': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/75',
#                                                                'http://ons.floop.org.uk/resource/topic/33',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC6214EW 2',
#                                                    'name': 'Occupation by '
#                                                            'religion',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1008': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/150',
#                                                                'http://ons.floop.org.uk/resource/topic/301',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'KS610EW 2',
#                                                    'name': 'Occupation - '
#                                                            'Females',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1009': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/99',
#                                                                'http://ons.floop.org.uk/resource/topic/100',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'KS206EW',
#                                                    'name': 'Household language',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1010': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/82',
#                                                                'http://ons.floop.org.uk/resource/topic/176',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC6215EW 2',
#                                                    'name': 'Economic activity '
#                                                            'by passports held',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1011': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/82',
#                                                                'http://ons.floop.org.uk/resource/topic/75',
#                                                                'http://ons.floop.org.uk/resource/topic/85'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC6603EW',
#                                                    'name': 'Occupation by '
#                                                            'economic activity '
#                                                            'by age',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1012': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/89',
#                                                                'http://ons.floop.org.uk/resource/topic/96'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'QS611EW',
#                                                    'name': 'Approximated '
#                                                            'social grade',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1013': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/182',
#                                                                'http://ons.floop.org.uk/resource/topic/84',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC3303EWr',
#                                                    'name': 'Provision of '
#                                                            'unpaid care by '
#                                                            'general health by '
#                                                            'sex by age '
#                                                            '(regional)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1014': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64',
#                                                                'http://ons.floop.org.uk/resource/topic/334',
#                                                                'http://ons.floop.org.uk/resource/topic/336',
#                                                                'http://ons.floop.org.uk/resource/topic/335'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'FDISUM',
#                                                    'name': 'Foreign Direct '
#                                                            'Investment - '
#                                                            'Earnings, Flows '
#                                                            'and Investment '
#                                                            'Positions',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1015': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/84',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'OT301EW',
#                                                    'name': 'Provision of '
#                                                            'unpaid care (Out '
#                                                            'of term-time '
#                                                            'population)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1016': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/182',
#                                                                'http://ons.floop.org.uk/resource/topic/145',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC2303EW',
#                                                    'name': 'Proficiency in '
#                                                            'English by general '
#                                                            'health by sex by '
#                                                            'age',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1017': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/151',
#                                                                'http://ons.floop.org.uk/resource/topic/33',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC2204EW',
#                                                    'name': 'National identity '
#                                                            'by religion',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1018': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/254',
#                                                                'http://ons.floop.org.uk/resource/topic/46',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'OCSIZE',
#                                                    'name': 'Output in the '
#                                                            'Construction '
#                                                            'Industry Sizebands',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1019': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/61',
#                                                                'http://ons.floop.org.uk/resource/topic/65',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC3405EW 2',
#                                                    'name': 'Long-term health '
#                                                            'problem or '
#                                                            'disability by car '
#                                                            'or van '
#                                                            'availability by '
#                                                            'sex',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1020': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/82',
#                                                                'http://ons.floop.org.uk/resource/topic/128',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC6401EW 2',
#                                                    'name': 'Economic activity '
#                                                            'by living '
#                                                            'arrangements',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1021': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/52',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'OT607EW 2',
#                                                    'name': 'NS-SeC (Out of '
#                                                            'term-time '
#                                                            'population)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1022': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/131',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64',
#                                                                'http://ons.floop.org.uk/resource/topic/337'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'HTYPKP',
#                                                    'name': 'Summary of the '
#                                                            'effects of taxes '
#                                                            'and benefits, in '
#                                                            '2013/14 prices',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1023': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/80',
#                                                                'http://ons.floop.org.uk/resource/topic/65',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC3205EW 2',
#                                                    'name': 'Long-term health '
#                                                            'problem or '
#                                                            'disability by '
#                                                            'ethnic group by '
#                                                            'sex by age',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1024': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/282',
#                                                                'http://ons.floop.org.uk/resource/topic/302',
#                                                                'http://ons.floop.org.uk/resource/topic/303',
#                                                                'http://ons.floop.org.uk/resource/topic/189',
#                                                                'http://ons.floop.org.uk/resource/topic/304',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'RSI',
#                                                    'name': 'Retail Sales',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1025': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/94',
#                                                                'http://ons.floop.org.uk/resource/topic/74',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/79'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC7608EWla',
#                                                    'name': 'Distance travelled '
#                                                            'to work by NS-SeC '
#                                                            'by sex',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1026': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/98',
#                                                                'http://ons.floop.org.uk/resource/topic/180',
#                                                                'http://ons.floop.org.uk/resource/topic/63',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC4407EW',
#                                                    'name': 'Tenure by number '
#                                                            'of persons per '
#                                                            'bedroom in '
#                                                            'household by '
#                                                            'accommodation type',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1027': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/69',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'OT501EW 2',
#                                                    'name': 'Highest level of '
#                                                            'qualification (Out '
#                                                            'of term-time '
#                                                            'population)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1028': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/86'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': '2014SNPP',
#                                                    'name': 'Projected '
#                                                            'Population, '
#                                                            '2014-based '
#                                                            'Subnational '
#                                                            'Population '
#                                                            'Projections',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1029': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/298',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'OT204EW',
#                                                    'name': 'Main language '
#                                                            '(detailed) (Out of '
#                                                            'term-time '
#                                                            'population)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1030': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/300',
#                                                                'http://ons.floop.org.uk/resource/topic/130',
#                                                                'http://ons.floop.org.uk/resource/topic/79'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC1103WAla',
#                                                    'name': 'Extended Welsh '
#                                                            'household '
#                                                            'composition by age '
#                                                            'of youngest '
#                                                            'dependent child',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1031': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/218',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC6123EW 2',
#                                                    'name': 'Former occupation '
#                                                            'by sex',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1032': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/125',
#                                                                'http://ons.floop.org.uk/resource/topic/67'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'WD212EW 2',
#                                                    'name': 'Passports held '
#                                                            '(detailed) '
#                                                            '(Workday '
#                                                            'population)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1033': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/69',
#                                                                'http://ons.floop.org.uk/resource/topic/33',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC5204EW',
#                                                    'name': 'Highest level of '
#                                                            'qualification by '
#                                                            'religion',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1034': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/68',
#                                                                'http://ons.floop.org.uk/resource/topic/69',
#                                                                'http://ons.floop.org.uk/resource/topic/85'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC5106EW',
#                                                    'name': 'Highest level of '
#                                                            'qualification by '
#                                                            'family type',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1035': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/137',
#                                                                'http://ons.floop.org.uk/resource/topic/70',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64',
#                                                                'http://ons.floop.org.uk/resource/topic/338'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'JOBS2',
#                                                    'name': 'Workforce Jobs by '
#                                                            'Industry',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1036': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/11',
#                                                                'http://ons.floop.org.uk/resource/topic/79'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'ST203EWla',
#                                                    'name': 'Country of birth '
#                                                            '(detailed) (non-UK '
#                                                            'born short-term '
#                                                            'residents)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1037': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/90',
#                                                                'http://ons.floop.org.uk/resource/topic/91',
#                                                                'http://ons.floop.org.uk/resource/topic/92',
#                                                                'http://ons.floop.org.uk/resource/topic/71'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'WP102EW',
#                                                    'name': 'Population '
#                                                            'densityÂ\xa0'
#                                                            '(Workplace '
#                                                            'population)',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1038': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/69',
#                                                                'http://ons.floop.org.uk/resource/topic/176',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'LC5206EW',
#                                                    'name': 'Highest level of '
#                                                            'qualification by '
#                                                            'passports held',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1039': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/142',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/79',
#                                                                'http://ons.floop.org.uk/resource/topic/339'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC4211EWla',
#                                                    'name': 'Communal '
#                                                            'establishment '
#                                                            'management and '
#                                                            'type by ethnic '
#                                                            'group by sex',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1040': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/80',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC2116EW 2',
#                                                    'name': 'Ethnic group of '
#                                                            'dependent child by '
#                                                            'sex',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1041': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/150',
#                                                                'http://ons.floop.org.uk/resource/topic/301',
#                                                                'http://ons.floop.org.uk/resource/topic/64'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'KS609EW',
#                                                    'name': 'Occupation - Males',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1042': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/32',
#                                                                'http://ons.floop.org.uk/resource/topic/66',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/275'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': '2012SNPP',
#                                                    'name': 'Projected '
#                                                            'Population, '
#                                                            '2012-based '
#                                                            'Subnational '
#                                                            'Population '
#                                                            'Projections',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1043': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/190',
#                                                                'http://ons.floop.org.uk/resource/topic/77',
#                                                                'http://ons.floop.org.uk/resource/topic/63',
#                                                                'http://ons.floop.org.uk/resource/topic/85'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC4405EW',
#                                                    'name': 'Tenure by '
#                                                            'household size by '
#                                                            'number of bedrooms',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1044': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/98',
#                                                                'http://ons.floop.org.uk/resource/topic/61',
#                                                                'http://ons.floop.org.uk/resource/topic/294',
#                                                                'http://ons.floop.org.uk/resource/topic/79'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC4415EWla',
#                                                    'name': 'Accommodation type '
#                                                            'by car or van '
#                                                            'availability by '
#                                                            'number of usual '
#                                                            'residents aged 17 '
#                                                            'or over in '
#                                                            'household',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1045': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64',
#                                                                'http://ons.floop.org.uk/resource/topic/340'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'OCTYPE',
#                                                    'name': 'Output in the '
#                                                            'Construction '
#                                                            'Industry Type of '
#                                                            'Work',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1046': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/142',
#                                                                'http://ons.floop.org.uk/resource/topic/146',
#                                                                'http://ons.floop.org.uk/resource/topic/85'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'DC4110EW',
#                                                    'name': 'Communal '
#                                                            'establishment '
#                                                            'management and '
#                                                            'type by position '
#                                                            'in communal '
#                                                            'establishment by '
#                                                            'age',
#                                                    'type': 'http://ons.floop.org.uk/resource/organisation/24'},
#  'http://ons.floop.org.uk/resource/dataset/1047': {'dependedOnBy': [],
#                                                    'depends': ['http://ons.floop.org.uk/resource/topic/258',
#                                                                'http://ons.floop.org.uk/resource/topic/107',
#                                                                'http://ons.floop.org.uk/resource/topic/64',
#                                                                'http://ons.floop.org.uk/resource/topic/341'],
#                                                    'docslink': 'https://www.ons.gov.uk/',
#                                                    'id': 'MQ5AAL',
#                                                    'name': 'Assets and '
#                                                            'liabilities of '
#                                                            'insurance '
# ...
#                                                'name': 'ethnic group of '
#                                                        'household reference '
#                                                        'person',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/63': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/63',
#                                                'name': 'tenure of household',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/64': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/64',
#                                                'name': '2011 statistical '
#                                                        'geography hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/65': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/65',
#                                                'name': 'long-term health '
#                                                        'problem or disability',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/66': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/66',
#                                                'name': 'sex',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/67': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/67',
#                                                'name': '2011 built-up area '
#                                                        'hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/68': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/68',
#                                                'name': 'family type',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/69': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/69',
#                                                'name': 'highest level of '
#                                                        'qualification',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/70': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/70',
#                                                'name': 'industry',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/71': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/71',
#                                                'name': '2011 workplace zone '
#                                                        'hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/72': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/72',
#                                                'name': 'method of travel to '
#                                                        'work (2001 '
#                                                        'specification)',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/73': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/73',
#                                                'name': 'ability to speak welsh '
#                                                        'language',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/74': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/74',
#                                                'name': 'national statistics '
#                                                        'socio-economic '
#                                                        'classification',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/75': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/75',
#                                                'name': 'occupation (major '
#                                                        'group)',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/76': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/76',
#                                                'name': 'age of dependent child',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/77': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/77',
#                                                'name': 'number of bedrooms',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/78': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/78',
#                                                'name': 'length of residence in '
#                                                        'the uk',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/79': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/79',
#                                                'name': '2011 census merged '
#                                                        'local authority '
#                                                        'district hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/80': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/80',
#                                                'name': 'ethnic group',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/81': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/81',
#                                                'name': 'hours worked',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/82': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/82',
#                                                'name': 'economic activity',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/83': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/83',
#                                                'name': 'number of people in '
#                                                        'household with a '
#                                                        'long-term health '
#                                                        'problem or disability',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/84': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/84',
#                                                'name': 'provision of unpaid '
#                                                        'care',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/85': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/85',
#                                                'name': '2011 census merged '
#                                                        'ward hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/86': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/86',
#                                                'name': '2014 administrative '
#                                                        'hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/87': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/87',
#                                                'name': 'household composition',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/88': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/88',
#                                                'name': 'adult lifestage',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/89': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/89',
#                                                'name': 'approximated social '
#                                                        'grade',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/90': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/90',
#                                                'name': 'all usual residents',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/91': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/91',
#                                                'name': 'area (hectares)',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/92': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/92',
#                                                'name': 'density (persons per '
#                                                        'hectare)',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/93': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/93',
#                                                'name': 'occupancy rating '
#                                                        '(bedrooms)',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/94': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/94',
#                                                'name': 'distance travelled to '
#                                                        'work and place of work '
#                                                        'indicator',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/95': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/95',
#                                                'name': 'living arrangements '
#                                                        '(extended)',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/96': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/96',
#                                                'name': '2011 westminster '
#                                                        'parliamentary '
#                                                        'constituency hierarchy',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/97': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/97',
#                                                'name': 'former industry',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/98': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/98',
#                                                'name': 'accommodation type',
#                                                'type': 'topic'},
#  'http://ons.floop.org.uk/resource/topic/99': {'dependedOnBy': [],
#                                                'depends': [],
#                                                'id': 'http://ons.floop.org.uk/resource/topic/99',
#                                                'name': 'english as a household '
#                                                        'language',
#                                                'type': 'topic'}}

# %% [markdown]
# ## Make the combined file

# %%
# Build the Combined Json
with open("data.json", "r") as main_file:   
    final = json.load(main_file)

    for key in ammendments.keys():
        final.update({key:ammendments[key]})
        
# Export to our final hacked json file
with open("FINAL_WDAhackedintofloopdata.json", "w") as outfile:
    json.dump(final, outfile)
